# %%
import sqlalchemy as db
import pandas as pd
import numpy as np
import psycopg2 as p
import os

# %%
df = pd.read_csv('resources/neighborhood_tier_final.csv')
df.head()
# Out:
#    postal_code State       City       CountyName    2021  total_restaurants  \
# 0        37013    TN  Nashville  Davidson County  295552                 83
# 1        37211    TN  Nashville  Davidson County  340382                182
# 2        37221    TN  Nashville  Davidson County  401000                 69
# 3        37209    TN  Nashville  Davidson County  445902                147
# 4        37076    TN  Nashville  Davidson County  328591                 81
#
#    avg_stars  total_reviews  BubbleTea  Coffee&Tea  ...  stars_1.0_ratio  \
# 0   3.096386         4257.0        0.0         4.0  ...         0.036145
# 1   3.491758        12761.0        2.0        12.0  ...         0.027473
# 2   3.217391         6690.0        0.0         3.0  ...         0.014493
# 3   3.772109        16663.0        0.0        10.0  ...         0.006803
# 4   3.228395         4994.0        0.0         4.0  ...         0.012346
#
# ...

# %%
cols = df.columns.to_list()
lower_case_cols = [x.lower() for x in cols]

# %%
df.columns = lower_case_cols

# %%
df.to_csv('resources/neighborhood_tier_final_upload.csv', index=False)

# %%
df2 = pd.read_csv('resources/neighborhood_tier_final_upload.csv')

# %%
db_path = f'postgresql://postgres:{awspd}@database-1.cx3jpmtuzudq.us-west-1.rds.amazonaws.com/postgres' # last item is name of db
# Create database engine
engine = db.create_engine(db_path)
connection = engine.connect()

# %%
df2.to_sql(name='neighborhood', con=engine)
#Close the DB connection
connection.close()
